# %%
# !pip install transformers torch

# %%
from transformers import pipeline

# %% [markdown]
# BART = encoder–decoder Transformer
#
# MNLI = trained on Natural Language Inference
#
# Not trained for sentiment or topic classification

# %%
classifier = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli"
)
# Out:
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]

# %%
text = "The course content was informative but very fast paced."

labels = ["positive", "negative", "neutral"]

# %%
result = classifier(text, labels)

print(result)
# Out:
# {'sequence': 'The course content was informative but very fast paced.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.8800008296966553, 0.07715177536010742, 0.04284742474555969]}

# %% [markdown]
# TRY:
# text = "Government introduces new AI data protection laws"
#
# labels = ["technology", "politics", "sports", "health"]
#
# classifier(text, labels)
#
#
# text = "Scientists confirm water found on Mars"
#
# labels = ["real news", "fake news"]
#
# classifier(text, labels)

# %%
# ONE SHOT LEARNING
# !pip install transformers torch sentencepiece

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small")

def custom_classifier(prompt, max_new_tokens=50):
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_new_tokens=max_new_tokens)
    decoded_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return [{"generated_text": decoded_text}]

classifier = custom_classifier
# Out:
# Loading weights:   0%|          | 0/190 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning

# %%
prompt = """
Classify the sentiment of the feedback.

Example:
Feedback: "The class was very interesting"
Sentiment: Positive

Now classify:
Feedback: "The lab sessions were confusing"
Sentiment:
"""

# %%
result = classifier(prompt, max_new_tokens=10)
print(result[0]["generated_text"])
# Out:
# negative

# %%
#few shot learrning
from transformers import pipeline

# The 'text2text-generation' task is not recognized by this version of transformers.pipeline.
# We will continue to use the custom classifier defined previously in the notebook.
# classifier = pipeline(
#     "text2text-generation",
#     model="google/flan-t5-small"
# )

# %%
prompt = """
Classify the sentiment of the feedback.

Examples:
Feedback: "The class was very interesting"
Sentiment: Positive

Feedback: "The instructor explained concepts clearly"
Sentiment: Positive

Feedback: "The lab sessions were boring"
Sentiment: Negative

Now classify:
Feedback: "The lab sessions were confusing"
Sentiment:
"""

# %%
result = classifier(prompt, max_new_tokens=10)
print(result[0]["generated_text"])
# Out:
# Negative

# %% [markdown]
# | Type      | Examples in Prompt |
# | --------- | ------------------ |
# | Zero-shot | 0                  |
# | One-shot  | 1                  |
# | Few-shot  | 2–5                |

# %%
#try
prompt = """
Classify student performance.

Examples:
Marks: 95
Grade: S

Marks: 72
Grade: B

Now classify:
Marks: 85
Grade:
"""
